# %% [markdown]
# <a href="https://colab.research.google.com/github/iluciferos/Praktikum-Algoritma-Pemrograman-Polines-25/blob/Jobsheet-9/Jobsheet_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PRAKTIKUM**

# %% [markdown]
# ### Praktikum 01 – Menggunakan Modul math

# %%
import math

angka = 16
hasil1 = math.sqrt(angka)
hasil2 = math.pow(2, 5)
print("Akar kuadrat dari", angka, "=", hasil1)
print("2 pangkat 5 = ", hasil2)
# Out:
# Akar kuadrat dari 16 = 4.0
# 2 pangkat 5 =  32.0

# %% [markdown]
# ### Praktikum 02 – Menggunakan from ... import ...

# %%
from math import sqrt

angka = 25
hasil = sqrt(angka)
print("Akar kuadrat dari angka 25 adalah ", hasil)
# Out:
# Akar kuadrat dari angka 25 adalah  5.0

# %% [markdown]
# ### Praktikum 03 – Memberi Alias Modul

# %%
import numpy as np

data = np.array([1, 2, 3])
print("isi array = ", data)
# Out:
# isi array =  [1 2 3]

# %% [markdown]
# ### Praktikum 04 – Eksplorasi math, random, dan sys

# %%
import math
import random
import sys

hasil1 = math.sqrt(81)
hasil2 = random.randint(1, 10)
version = sys.version
print("Hasil kuadrat dari 81 adalah", hasil1)
print("Hasil angka acak dari 1-10 adalah", hasil2)
print("versi phyton = ", version)
# Out:
# Hasil kuadrat dari 81 adalah 9.0
# Hasil angka acak dari 1-10 adalah 8
# versi phyton =  3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# ### Praktikum 05 – Membuat Modul Sendiri

# %%
# %%writefile modulku.py
def halo(nama):
    print(f"Halo, {nama}! Selamat belajar Phyton di Polines.")
# Out:
# Writing modulku.py

# %%
import modulku

modulku.halo("Mahasiswa Polines")
# Out:
# Halo, Mahasiswa Polines! Selamat belajar Phyton di Polines.

# %% [markdown]
# ### Praktikum 06 – Instalasi Modul dengan pip

# %%
# !pip install requests

# %%
import requests

response = requests.get("https://polines.ac.id")
print("Status code: ", response.status_code)
# Out:
# Status code:  403

# %% [markdown]
# # **PENUGASAN**

# %% [markdown]
# ### Eksperimen dengan Modul math

# %%
import math

r = int(input("Masukkan jari-jari lingkaran = "))
luaslingkaran = math.pi * math.pow(r, 2)

print(luaslingkaran)
# Out:
# Masukkan jari-jari lingkaran = 7
# 153.93804002589985

# %% [markdown]
# ### Eksperimen dengan Modul random

# %%
import random

hasil = random.sample(range(1, 101), 5)

print(hasil)
# Out:
# [59, 22, 32, 61, 18]

# %% [markdown]
# ### Modul sys

# %%
import sys

ver1 = sys.platform
ver2 = sys.version

print("Platform yang digunakan adalah", ver1)
print("Versi phyton",ver2)
# Out:
# Platform yang digunakan adalah linux
# Versi phyton 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# ### Modul Buatan Sendiri

# %%
# %%writefile konversisuhu.py

def cel_to_fah(c):
    fahrenheit = (c * 9/5) + 32
    return fahrenheit

def fah_to_cel(f):
    celcius = (f - 32) * 5/9
    return celcius
# Out:
# Writing konversisuhu.py

# %%
import konversisuhu

suhu_c = int(input("Masukkan suhu dalam celcius = "))
suhu_f =konversisuhu.cel_to_fah(suhu_c)
print(f"{suhu_c}°C = {suhu_f}°F")

suhu_f2 = int(input("Masukkan suhu dalam fahrenheit = "))
suhu_c2 = konversisuhu.fah_to_cel(suhu_f2)
print(f"{suhu_f2}°F = {suhu_c2}°C")
# Out:
# Masukkan suhu dalam celcius = 25
# 25°C = 77.0°F
# Masukkan suhu dalam fahrenheit = 77
# 77°F = 25.0°C

# %% [markdown]
# ### Instalasi Library Pihak Ketiga

# %%
# !pip install pandas

# %%
import pandas as pd

data_mahasiswa = {
    'NIM': ['2301001', '2301002', '2301003', '2301004', '2301005'],
    'Nama': ['Budi Santoso', 'Ani Wijaya', 'Citra Dewi', 'Doni Pratama', 'Eka Putri'],
    'Prodi': ['Informatika', 'Sistem Informasi', 'Informatika', 'Teknik Komputer', 'Sistem Informasi']
}

df_mahasiswa = pd.DataFrame(data_mahasiswa)

print("Data Mahasiswa:")
print(df_mahasiswa)
# Out:
# Data Mahasiswa:
#        NIM          Nama             Prodi
# 0  2301001  Budi Santoso       Informatika
# 1  2301002    Ani Wijaya  Sistem Informasi
# 2  2301003    Citra Dewi       Informatika
# 3  2301004  Doni Pratama   Teknik Komputer
# 4  2301005     Eka Putri  Sistem Informasi

# %% [markdown]
# ### Studi Kasus Mini

# %%
# %%writefile laporan.py

def tampilkan_skor(benar, salah):
    """Menampilkan ringkasan skor"""
    total = benar + salah
    skor = (benar / total) * 100

    print("\n" + "="*40)
    print("HASIL KUIS")
    print("="*40)
    print(f"Benar  : {benar}")
    print(f"Salah  : {salah}")
    print(f"Skor   : {skor:.0f}")
    print("="*40)
# Out:
# Writing laporan.py

# %%
import random
import laporan

jumlah_soal = 5

benar = 0
salah = 0

print("KUIS PENJUMLAHAN")
print("="*40)

for i in range(1, jumlah_soal + 1):
    angka1 = random.randint(1, 20)
    angka2 = random.randint(1, 20)
    jawaban_benar = angka1 + angka2

    print(f"\nSoal {i}: {angka1} + {angka2} = ?")
    jawaban = int(input("Jawaban: "))

    if jawaban == jawaban_benar:
        print("✓ Benar!")
        benar += 1
    else:
        print(f"✗ Salah! Jawaban: {jawaban_benar}")
        salah += 1

laporan.tampilkan_skor(benar, salah)
# Out:
# KUIS PENJUMLAHAN
# ...
#
# Soal 1: 2 + 12 = ?
# Jawaban: 14
# ✓ Benar!
#
# Soal 2: 4 + 4 = ?
# Jawaban: 8
# ✓ Benar!
#
# Soal 3: 7 + 9 = ?
# Jawaban: 16
# ✓ Benar!
#
# Soal 4: 10 + 2 = ?
# Jawaban: 12
# ✓ Benar!
#
# Soal 5: 8 + 10 = ?
# Jawaban: 18
# ✓ Benar!
#
# ...
# HASIL KUIS
# ...
# Benar  : 5
# Salah  : 0
# Skor   : 100
# ...
